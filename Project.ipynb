# %%
class Mobile:
    def __init__(self):
        self.a = ''
        self.b = ''

    def getans1(self):
        self.a = input('Do you want a mobile? Type (yes/no): ').lower()
        if self.a == 'yes':
            self.getans2()
        elif self.a == 'no':
            print('Thank you, visit again.')
        else:
            print('Please type a correct sentence.')
            self.getans1()

    def getans2(self):
        self.a = input('Which phone do you want? Type (samsung/iphone): ').lower()
        if self.a == 'samsung' or self.a == 'iphone':
            print(f'You have selected {self.a}.')
            if self.a == 'samsung':
                self.getans3()
            elif self.a == 'iphone':
                self.getans4()
        else:
            print('Please type the correct mobile name.')
            self.getans2()

    def getans3(self):
        self.b = input('Please select model (s24/a15/zflip): ').lower()
        models = ('s24', 'a15', 'zflip')
        if self.b in models:
            print(f"You selected {self.b}.")
            self.getans5()
        else:
            print('Please type the correct model.')
            self.getans3()

    def getans4(self):
        self.b = input('Please select model (13,14,15): ').lower()
        models = ('13', '14', '15')
        if self.b in models:
            print(f'You selected {self.b}.')
            self.getans5()
        else:
            print('Please type the correct model.')
            self.getans4()

    def getans5(self):
        self.s = input('Select the size (128gb/256gb): ').lower()
        if self.s == '128gb' or self.s == '256gb':
            if self.a == 'samsung':
                self.getans6()
            elif self.a == 'iphone':
                self.getans7()
        else:
            print('Please type the correct size.')
            self.getans5()

    def getans6(self):
        if self.s == '128gb' and self.b in ['s24','a15','zflip']:
            self.c = input('Select the color (red/green/white): ').lower()
            print(f'The color selected {self.c}')
        elif self.s == '256gb' and self.b in ['s24','a15','zflip']:
            self.c = input('Select the color (blue/black/orange): ').lower()
            print(f'The color selected {self.c}')
        else:
            print('Thank you.')

    def getans7(self):
        if self.s == '128gb' and self.b in['13','14','15']:
            self.c = input('Select the color (red/green/white): ').lower()
            print(f'The color selected {self.c}')
        elif self.s == '256gb' and self.b in ['13','14','15']:
            self.c = input('Select the color (blue/black/orange): ').lower()
            print(f'The color selected {self.c}')
        else:
            print('Thank you.')

    def mobile(self):
        if self.a=='samsung':
            if self.b=='s24':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='50 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.batt='4000 mAh'
                        self.sim='dual nano sim slots'
                        self.char='type c 45w charger'
                        self.price='₹ 64,999'

                    elif self.c =='green':
                        self.cam='50 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.batt='4000 mAh'
                        self.sim='dual nano sim slots'
                        self.char='type c 45w charger'
                        self.price='₹ 65,999'
                    elif self.c =='white':
                        self.cam='50 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.batt='4000 mAh'
                        self.sim='dual nano sim slots'
                        self.char='type c 45w charger'
                        self.price='₹ 62,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

            elif self.b =='a15':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                    elif self.c == 'green':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c == 'white':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

            elif self.b =='zflip':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                    elif self.c == 'green':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c == 'white':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'


        elif self.a=='iphone':
            if self.b=='13':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                    elif self.c == 'green':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c == 'white':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

            elif self.b =='14':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                    elif self.c == 'green':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c == 'white':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

            elif self.b =='15':
                if self.s=='128gb':
                    if self.c =='red':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                    elif self.c == 'green':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c == 'white':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'

                elif self.s == '256gb':
                    if self.c =='blue':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='black':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'
                    elif self.c =='orange':
                        self.cam='60 MEGA PIXEL'
                        self.dis='6.2 inches'
                        self.sim='2 sim slots'
                        self.char='69% nice'
                        self.price='₹ 89,999'


    def feature(self):
        print('=========================================================')
        print('SELECTED MOBILE IS:',self.a)
        print('SELECTED MODEL IS:',self.b)
        print('SELECTED COLOUR IS:',self.c)
        print('SELECTED SIZE IS:',self.s)
        print('CAMERA FEATURES:',self.cam)
        print('DISPLAY FEATURES:',self.dis)
        print('SIM FEATURES:',self.sim)
        print('CHARGER FEATURES:',self.char)
        print('PRICE OF THE SELECTED MOBILE :',self.price)
            
            
web = Mobile()
web.getans1()
web.mobile()
web.feature()
# Out:
# You have selected iphone.
# Please type the correct model.
# You selected 13.
# The color selected black
# ...
# SELECTED MOBILE IS: iphone
# SELECTED MODEL IS: 13
# SELECTED COLOUR IS: black
# SELECTED SIZE IS: 256gb
# CAMERA FEATURES: 60 MEGA PIXEL
# DISPLAY FEATURES: 6.2 inches
# SIM FEATURES: 2 sim slots
# CHARGER FEATURES: 69% nice
# PRICE OF THE SELECTED MOBILE : ₹ 89,999
